# %%
import pandas as pd

# %%
df = pd.read_csv('heart_2020_cleaned_copy.csv')

# %%
df.loc[df['HeartDisease'] == 1]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 5                  1  28.87        1               -1      -1             6.0
# 10                 1  34.30        1               -1      -1            30.0
# 35                 1  32.98        1               -1       1            10.0
# 42                 1  25.06       -1               -1      -1             0.0
# 43                 1  30.23        1               -1      -1             6.0
# ...              ...    ...      ...              ...     ...             ...
# 319765             1  38.45       -1               -1       1            30.0
# 319767             1  36.21        1               -1      -1             0.0
# 319781             1  37.12        1               -1      -1             0.0
# 319786             1  33.20        1               -1      -1             0.0
# 319790             1  27.41        1               -1      -1             7.0
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 5                0.0            1    2           12     2        -1
# 10               0.0            1    1            9     1         1
# 35               0.0            1    1           12     1         1
# 42               0.0            1    2           13     1         1
# 43               2.0            1    2           12     1         1
# ...              ...          ...  ...          ...   ...       ...
# 319765          15.0            1    2            8     5         1
# 319767           0.0            1    2           12     5         1
# 319781           0.0           -1    1            4     5        -1
# 319786           0.0           -1    2            9     5         1
# 319790           0.0            1    1            9     5         1
#
#         PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  \
# 5                     -1          4       12.0      -1             -1
# 10                    -1          5       15.0       1             -1
# 35                     1          5        4.0      -1             -1
# 42                    -1          3        7.0      -1             -1
# 43                     1          4        8.0      -1              1
# ...                  ...        ...        ...     ...            ...
# 319765                 1          5        6.0       1             -1
# 319767                 1          3        8.0      -1             -1
# 319781                 1          2        7.0      -1             -1
# 319786                 1          2        8.0       1             -1
# 319790                -1          4        6.0       1             -1
#
#         SkinCancer
# 5               -1
# 10              -1
# 35               1
# 42               1
# 43              -1
# ...            ...
# 319765          -1
# 319767          -1
# 319781          -1
# 319786          -1
# 319790          -1
#
# [27373 rows x 18 columns]

# %%
display (df.loc[295580])
# Out:
# HeartDisease        -1.00
# BMI                 29.23
# Smoking              1.00
# AlcoholDrinking     -1.00
# Stroke              -1.00
# PhysicalHealth       0.00
# MentalHealth         9.00
# DiffWalking         -1.00
# Sex                  2.00
# AgeCategory          4.00
# Race                 1.00
# Diabetic            -1.00
# PhysicalActivity     1.00
# GenHealth            2.00
# SleepTime            5.00
# Asthma              -1.00
# KidneyDisease       -1.00
# SkinCancer          -1.00
# Name: 295580, dtype: float64

# %%
df = df.drop(['Race','DiffWalking', 'GenHealth'], axis=1)

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0            -1  16.60        1               -1      -1             3.0
# 1            -1  20.34       -1               -1       1             0.0
# 2            -1  26.58        1               -1      -1            20.0
# 3            -1  24.21       -1               -1      -1             0.0
# 4            -1  23.71       -1               -1      -1            28.0
#
#    MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# 0          30.0    2            8         1                 1        5.0
# 1           0.0    2           13        -1                 1        7.0
# 2          30.0    1           10         1                 1        8.0
# 3           0.0    2           12        -1                -1        6.0
# 4           0.0    2            5        -1                 1        8.0
#
#    Asthma  KidneyDisease  SkinCancer
# 0       1             -1           1
# 1      -1             -1          -1
# 2       1             -1          -1
# 3      -1             -1           1
# 4      -1             -1          -1

# %%
linha_especifica = df.iloc[263380]

# %%
linha_especifica
# Out:
# HeartDisease        -1.00
# BMI                 25.61
# Smoking             -1.00
# AlcoholDrinking     -1.00
# Stroke              -1.00
# PhysicalHealth       4.00
# MentalHealth        15.00
# Sex                  2.00
# AgeCategory          1.00
# Diabetic            -1.00
# PhysicalActivity     1.00
# SleepTime            8.00
# Asthma               1.00
# KidneyDisease       -1.00
# SkinCancer          -1.00
# Name: 263380, dtype: float64
